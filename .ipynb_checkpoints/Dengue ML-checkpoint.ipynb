# %% [markdown]
# # Data preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset_no_shift = pd.read_csv('Better data 2019_2020.csv')
dataset_1_shift = pd.read_csv('Better data 2019_2020 shift_1.csv')
dataset_2_shift = pd.read_csv('Better data 2019_2020 shift_2.csv')
dataset_3_shift = pd.read_csv('Better data 2019_2020 shift_3.csv')
dataset_4_shift = pd.read_csv('Better data 2019_2020 shift_4.csv')
dataset_5_shift = pd.read_csv('Better data 2019_2020 shift_5.csv')

# %% [markdown]
# #### Seeing the correlations

# %% [markdown]
# ##### No shift

# %%
plt.figure()
plt.scatter(dataset_no_shift["Temp"], dataset_no_shift["Dengue_count"], c="red")
plt.xlabel("Temperature (Celcius)")
plt.ylabel("Dengue count")
plt.title("No shift, temp to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_no_shift["Temp"], dataset_no_shift["Dengue_count"])
print(r, p_value)
# Out:
# -0.16740650655426442 0.43428408860405543

# %% [markdown]
# Conclusion: There seems to be no correlation for temperature and dengue count within the same month.
# - Pearson coefficient of -0.167 means close to 0 and no correlation.
# - P value of > 0.05 means that the correlation is not real.

# %%
plt.figure()
plt.scatter(dataset_no_shift["Humidity"], dataset_no_shift["Dengue_count"], c="orange")
plt.xlabel("Humidity")
plt.ylabel("Dengue count")
plt.title("No shift, humidity to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_no_shift["Humidity"], dataset_no_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.4508384883491614 0.027032743055703905

# %% [markdown]
# Conclusion: There seems to be some correlation for temperature and dengue count within the same month.
# - Pearson coefficient of -0.451 means positive correlation (increasing slope).
# - P value of < 0.05 means that the correlation is real.

# %%
plt.figure()
plt.scatter(dataset_no_shift["Precipitation"], dataset_no_shift["Dengue_count"], c="yellow")
plt.xlabel("Precipitation")
plt.ylabel("Dengue count")
plt.title("No shift, precipitation to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_no_shift["Precipitation"], dataset_no_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.08846362046889039 0.6810333107295079

# %% [markdown]
# Conclusion: There seems to be barely any correlation between precipitation and dengue count within the same month.
# - Pearson coefficient of -0.088 means close to 0 and no correlation.
# - P value of > 0.05 means that the correlation is not real.

# %% [markdown]
# **Conclusion for 0 month shift: We will not be using this dataset as it doesn't highlight any pattern except humidity. The others with shifts do better.**

# %% [markdown]
# ##### 1-Month shift (dengue counts are after 1 month of a weather pattern occuring)

# %%
plt.figure()
plt.scatter(dataset_1_shift["Temp"], dataset_1_shift["Dengue_count"], c="lightgreen")
plt.xlabel("Temperature (Celcius)")
plt.ylabel("Dengue count")
plt.title("1 shift, temp to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_1_shift["Temp"], dataset_1_shift["Dengue_count"])
print(r, p_value)
# Out:
# -0.4139972682080379 0.04954403188298627

# %% [markdown]
# Conclusion: There seems to be barely any correlation for temperature and dengue count within one month shift.
# - Pearson coefficient of -0.414 means negative correlation (decreasing slope).
# - P value of < 0.05 means that the correlation is real, but it's barely scratching the border.

# %%
plt.figure()
plt.scatter(dataset_1_shift["Humidity"], dataset_1_shift["Dengue_count"], c="green")
plt.xlabel("Humidity")
plt.ylabel("Dengue count")
plt.title("1 shift, humidity to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_1_shift["Humidity"], dataset_1_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.5920311271660114 0.002919333579245134

# %% [markdown]
# Conclusion: There seems to be strong correlation for humidity and dengue count within one month shift.
# - Pearson coefficient of 0.592 means positive correlation (increasing slope).
# - P value of < 0.01 means that the correlation is real and very strong.

# %%
plt.figure()
plt.scatter(dataset_1_shift["Precipitation"], dataset_1_shift["Dengue_count"], c="cyan")
plt.xlabel("Precipitation")
plt.ylabel("Dengue count")
plt.title("1 shift, precipitation to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_1_shift["Precipitation"], dataset_1_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.2908488367025507 0.1781741867888729

# %% [markdown]
# Conclusion: There seems to be some correlation for precipitation and dengue count within one month shift.
# - Pearson coefficient of 0.291 means positive correlation (increasing slope), but not too strong.
# - P value of < 0.05 means that the correlation is real.

# %% [markdown]
# **Conclusion for 1 month shift: We will not be using this dataset even if we find some pattern in it because the 2 month shift is a better model.**

# %% [markdown]
# ##### 2-Month shift (dengue counts are after 2 months of a weather pattern occuring)

# %%
plt.figure()
plt.scatter(dataset_2_shift["Temp"], dataset_2_shift["Dengue_count"], c="blue")
plt.xlabel("Temperature (Celcius)")
plt.ylabel("Dengue count")
plt.title("2 shift, temp to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_2_shift["Temp"], dataset_2_shift["Dengue_count"])
print(r, p_value)
# Out:
# -0.5520221206843754 0.007729321655564818

# %% [markdown]
# Conclusion: There seems to be a strong pattern between temperature and the number of dengue count.
# - Pearson coefficient of -0.552 means negative correlation (decreasing slope).
# - P value of < 0.01 means that the correlation is real and very strong.

# %%
plt.figure()
plt.scatter(dataset_2_shift["Humidity"], dataset_2_shift["Dengue_count"], c="purple")
plt.xlabel("Humidity")
plt.ylabel("Dengue count")
plt.title("2 shift, humidity to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_2_shift["Humidity"], dataset_2_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.6377037600255484 0.001409290229135507

# %% [markdown]
# Conclusion: There seems to be a some pattern between humidity and the number of dengue count.
# - Pearson coefficient of 0.638 means strong positive correlation (increasing slope).
# - P value of < 0.05 means that the correlation is real. It nears 0.01 and is almost very strong.

# %%
plt.figure()
plt.scatter(dataset_2_shift["Precipitation"], dataset_2_shift["Dengue_count"], c="magenta")
plt.xlabel("Precipitation")
plt.ylabel("Dengue count")
plt.title("2 shift, precipitation to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_2_shift["Precipitation"], dataset_2_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.43015960502464834 0.04568958297172403

# %% [markdown]
# Conclusion: There seems to be a faint pattern between precipitation and the number of dengue count.
# - Pearson coefficient of 0.0.430 means positive correlation (increasing slope).
# - P value of < 0.05 means that the correlation is real.

# %% [markdown]
# **Conclusion for 2-month shift: We will be using this dataset despite it being a flimsy fit. It has the best r and p-values. Mosquitoes take 1-2 months to hatch and infect people. We will refine the data by removing outliers.**

# %% [markdown]
# ##### 3 Month Shift (dengue counts are after 3 months of a weather pattern occuring)

# %%
plt.figure()
plt.scatter(dataset_3_shift["Temp"], dataset_3_shift["Dengue_count"], c="red")
plt.xlabel("Temperature (Celcius)")
plt.ylabel("Dengue count")
plt.title("3 shift, temp to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_3_shift["Temp"], dataset_3_shift["Dengue_count"])
print(r, p_value)
# Out:
# -0.5572984913032281 0.008675058678889179

# %%
plt.figure()
plt.scatter(dataset_3_shift["Humidity"], dataset_3_shift["Dengue_count"], c="orange")
plt.xlabel("Humidity")
plt.ylabel("Dengue count")
plt.title("3 shift, humidity to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_3_shift["Humidity"], dataset_3_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.5989730854555044 0.004115940003344399

# %%
plt.figure()
plt.scatter(dataset_3_shift["Precipitation"], dataset_3_shift["Dengue_count"], c="yellow")
plt.xlabel("Precipitation")
plt.ylabel("Dengue count")
plt.title("3 shift, precipitation to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_3_shift["Precipitation"], dataset_3_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.4604292648547694 0.0356951454584783

# %% [markdown]
# Conclusion:
# - Temperature shows a strong negative correlation (r = -0.557, p = 0.009) — the strongest of any shift so far.
# - Humidity shows a strong positive correlation (r = 0.599, p = 0.004), consistent with shifts 1 and 2.
# - Precipitation shows a moderate positive correlation (r = 0.460, p = 0.036), also the strongest precipitation result so far.
#
# **Conclusion for 3-month shift: This shift performs comparably to (arguably slightly better than) 2-month shift across all three variables. Worth treating 2 and 3 months as a plausible window rather than picking one point value.**

# %% [markdown]
# ##### 4 Month Shift (dengue counts are after 4 months of a weather pattern occuring)

# %%
plt.figure()
plt.scatter(dataset_4_shift["Temp"], dataset_4_shift["Dengue_count"], c="red")
plt.xlabel("Temperature (Celcius)")
plt.ylabel("Dengue count")
plt.title("4 shift, temp to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_4_shift["Temp"], dataset_4_shift["Dengue_count"])
print(r, p_value)
# Out:
# -0.37610720627349875 0.10218402352870685

# %%
plt.figure()
plt.scatter(dataset_4_shift["Humidity"], dataset_4_shift["Dengue_count"], c="orange")
plt.xlabel("Humidity")
plt.ylabel("Dengue count")
plt.title("4 shift, humidity to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_4_shift["Humidity"], dataset_4_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.3730723875795526 0.10520668074716756

# %%
plt.figure()
plt.scatter(dataset_4_shift["Precipitation"], dataset_4_shift["Dengue_count"], c="yellow")
plt.xlabel("Precipitation")
plt.ylabel("Dengue count")
plt.title("4 shift, precipitation to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_4_shift["Precipitation"], dataset_4_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.3301228408519384 0.1551681143378595

# %% [markdown]
# Conclusion:
# - Temperature correlation weakens sharply and is no longer significant (r = -0.376, p = 0.102).
# - Humidity correlation also weakens and loses significance (r = 0.373, p = 0.105).
# - Precipitation correlation weakens further and is not significant (r = 0.330, p = 0.155).
#
# **Conclusion for 4-month shift: The pattern that was strong at 2–3 months has broken down here. None of the three variables clear p < 0.05.**

# %% [markdown]
# ##### 5 Month Shift (dengue counts are after 5 months of a weather pattern occuring)

# %%
plt.figure()
plt.scatter(dataset_5_shift["Temp"], dataset_5_shift["Dengue_count"], c="red")
plt.xlabel("Temperature (Celcius)")
plt.ylabel("Dengue count")
plt.title("5 shift, temp to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_5_shift["Temp"], dataset_5_shift["Dengue_count"])
print(r, p_value)
# Out:
# -0.1185151764328558 0.6289298502051343

# %%
plt.figure()
plt.scatter(dataset_5_shift["Humidity"], dataset_5_shift["Dengue_count"], c="orange")
plt.xlabel("Humidity")
plt.ylabel("Dengue count")
plt.title("5 shift, humidity to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_5_shift["Humidity"], dataset_5_shift["Dengue_count"])
print(r, p_value)
# Out:
# -0.03522260342406857 0.8861698963934885

# %%
plt.figure()
plt.scatter(dataset_5_shift["Precipitation"], dataset_5_shift["Dengue_count"], c="yellow")
plt.xlabel("Precipitation")
plt.ylabel("Dengue count")
plt.title("5 shift, precipitation to dengue count")
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(dataset_5_shift["Precipitation"], dataset_5_shift["Dengue_count"])
print(r, p_value)
# Out:
# 0.0533521147717019 0.8282689531574486

# %% [markdown]
# Conclusion:
# - All three variables are now essentially uncorrelated with dengue count (|r| < 0.12, all p > 0.6).
#
# **Conclusion for 5-month shift: No usable signal at all. Whatever relationship exists between weather and dengue counts, it has fully dissipated by 5 months.**

# %% [markdown]
# #### Correlation heatmaps

# %%
import seaborn as sns

# Compute correlations for each dataset (drop the non-numeric Year-Month column)
datasets = [
    (dataset_no_shift, "No Shift"),
    (dataset_1_shift,  "Shift 1 Month"),
    (dataset_2_shift,  "Shift 2 Months"),
    (dataset_3_shift,  "Shift 3 Months"),
    (dataset_4_shift,  "Shift 4 Months"),
    (dataset_5_shift,  "Shift 5 Months"),
]

fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()  # so we can index 0-5 in order, left-to-right, top-to-bottom

for ax, (df, label) in zip(axes, datasets):
    corr = df.drop(columns=['Year-Month']).corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, ax=ax)
    ax.set_title(f"Correlation Heatmap ({label})")

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion: Heatmaps show that direct (no-shift) correlation between weather variables and dengue cases is weak. After applying 1–2 month shifts, the correlations become stronger, especially humidity and precipitation, indicating a delayed effect consistent with mosquito breeding cycles.
#
# **New Conclusion:** Across all six shifts, correlation strength is not monotonic — it rises from shift 0 through a peak around shifts 2-3, then collapses by shift 4 and is gone entirely by shift 5. This peak-then-drop shape is more informative than any single shift's r-value: it suggests the true rainfall-to-case lag sits somewhere in the 2-3 month window, consistent with mosquito breeding/incubation cycles, rather than extending out toward the 5-month adult-lifespan figure. We will continue using the 2-month shift dataset (per the earlier decision), though 3-month is a close, defensible alternative — the two are similar enough that the difference between them is likely within noise given N≈20-22.

# %% [markdown]
# #### Bonferroni

# %%
import pandas as pd
from statsmodels.stats.multitest import multipletests

# All 18 correlation tests run across the 6 shift datasets
results = [
    (0, 'Temp', -0.167, 0.4343), (0, 'Humidity', 0.451, 0.0270), (0, 'Precipitation', 0.088, 0.6810),
    (1, 'Temp', -0.414, 0.0495), (1, 'Humidity', 0.592, 0.0029), (1, 'Precipitation', 0.291, 0.1782),
    (2, 'Temp', -0.552, 0.0077), (2, 'Humidity', 0.638, 0.0014), (2, 'Precipitation', 0.430, 0.0457),
    (3, 'Temp', -0.557, 0.0087), (3, 'Humidity', 0.599, 0.0041), (3, 'Precipitation', 0.460, 0.0357),
    (4, 'Temp', -0.376, 0.1022), (4, 'Humidity', 0.373, 0.1052), (4, 'Precipitation', 0.330, 0.1552),
    (5, 'Temp', -0.119, 0.6289), (5, 'Humidity', -0.035, 0.8862), (5, 'Precipitation', 0.053, 0.8283),
]
df = pd.DataFrame(results, columns=['shift', 'variable', 'r', 'p'])

_, bonf_p, _, _ = multipletests(df['p'], alpha=0.05, method='bonferroni')
_, bh_q,   _, _ = multipletests(df['p'], alpha=0.05, method='fdr_bh')

df['bonferroni_p'] = bonf_p.round(4)
df['bonferroni_sig'] = df['bonferroni_p'] < 0.05
df['bh_q'] = bh_q.round(4)
df['bh_sig'] = df['bh_q'] < 0.05

df.sort_values(['shift', 'variable'])
# Out:
#     shift       variable      r       p  bonferroni_p  bonferroni_sig    bh_q  \
# 1       0       Humidity  0.451  0.0270        0.4860           False  0.0810
# 2       0  Precipitation  0.088  0.6810        1.0000           False  0.7661
# 0       0           Temp -0.167  0.4343        1.0000           False  0.5584
# 4       1       Humidity  0.592  0.0029        0.0522           False  0.0246
# 5       1  Precipitation  0.291  0.1782        1.0000           False  0.2467
# 3       1           Temp -0.414  0.0495        0.8910           False  0.0990
# 7       2       Humidity  0.638  0.0014        0.0252            True  0.0246
# 8       2  Precipitation  0.430  0.0457        0.8226           False  0.0990
# 6       2           Temp -0.552  0.0077        0.1386           False  0.0313
# 10      3       Humidity  0.599  0.0041        0.0738           False  0.0246
# 11      3  Precipitation  0.460  0.0357        0.6426           False  0.0918
# ...

# %% [markdown]
# After correcting for multiple comparisons using the Benjamini-Hochberg procedure, humidity remained significantly associated with dengue case counts at 1-, 2-, and 3-month lags, and temperature at 2- and 3-month lags; only the humidity association at 2-month lag survived the more conservative Bonferroni correction. No associations were significant at 4- or 5-month lags."

# %% [markdown]
# #### Removing outliers by IQR

# %% [markdown]
# ##### Removing dengue count outliers

# %%
Q1_dengue = dataset_2_shift["Dengue_count"].quantile(0.25)
Q3_dengue = dataset_2_shift["Dengue_count"].quantile(0.75)
IQR_dengue = Q3_dengue - Q1_dengue

lower_dengue = Q1_dengue - 1.5 * IQR_dengue
upper_dengue = Q3_dengue + 1.5 * IQR_dengue

# %%
print(lower_dengue)
print(upper_dengue)
# Out:
# -1051.125
# 2181.875

# %% [markdown]
# 2 months shift: 3 nodes are removed from this process later.
#
# 3 months shift: 2 nodes are removed from this process later.

# %% [markdown]
# ##### Removing temperature outliers

# %%
Q1_temp = dataset_2_shift["Temp"].quantile(0.25)
Q3_temp = dataset_2_shift["Temp"].quantile(0.75)
IQR_temp = Q3_temp - Q1_temp

lower_temp = Q1_temp - 1.5 * IQR_temp
upper_temp = Q3_temp + 1.5 * IQR_temp

# %%
print(lower_temp)
print(upper_temp)
# Out:
# 27.16625
# 30.85625

# %% [markdown]
# Nothing has been removed.

# %% [markdown]
# ##### Removing humidity outliers

# %%
Q1_humidity = dataset_2_shift["Humidity"].quantile(0.25)
Q3_humidity = dataset_2_shift["Humidity"].quantile(0.75)
IQR_humidity = Q3_humidity - Q1_humidity

lower_humidity = Q1_humidity - 1.5 * IQR_humidity
upper_humidity = Q3_humidity + 1.5 * IQR_humidity

# %%
print(lower_humidity)
print(upper_humidity)
# Out:
# 58.02499999999999
# 90.62500000000001

# %% [markdown]
# Nothing has been removed.

# %% [markdown]
# ##### Removing precipitation outliers

# %%
Q1_precipitation = dataset_2_shift["Precipitation"].quantile(0.25)
Q3_precipitation = dataset_2_shift["Precipitation"].quantile(0.75)
IQR_precipitation = Q3_precipitation - Q1_precipitation

lower_precipitation = Q1_precipitation - 1.5 * IQR_precipitation
upper_precipitation = Q3_precipitation + 1.5 * IQR_precipitation

# %%
print(lower_precipitation)
print(upper_precipitation)
# Out:
# -244.04999999999998
# 491.15

# %% [markdown]
# 2 months shift: 3 nodes are removed from this process later... but nevermind, we don't need this.
#
# 3 months shift: 2 nodes are removed

# %% [markdown]
# Removal of data dengue count = 1700 because it is an anomaly (suddenly next month is 794)... Edit: we don't need this either. No eyeballing I guess, just statistical IQR outlier removal is enough.

# %%
# forced_outlier_value = 1700

# %% [markdown]
# ##### The actual removal process

# %%
# values kept (inliers)
inliers = dataset_2_shift[
    (dataset_2_shift["Dengue_count"] >= lower_dengue) &
    (dataset_2_shift["Dengue_count"] <= upper_dengue) 
#    (dataset_2_shift["Temp"] >= lower_temp) &
#    (dataset_2_shift["Temp"] <= upper_temp) &
#    (dataset_2_shift["Humidity"] >= lower_humidity) &
#    (dataset_2_shift["Humidity"] <= upper_humidity) &
#    (dataset_2_shift["Precipitation"] >= lower_precipitation) &
#    (dataset_2_shift["Precipitation"] <= upper_precipitation) &
#    (dataset_2_shift["Dengue_count"] != forced_outlier_value)
]

# values removed (outliers)
outliers = dataset_2_shift[
    (dataset_2_shift["Dengue_count"] < lower_dengue) |
    (dataset_2_shift["Dengue_count"] > upper_dengue) 
#    (dataset_2_shift["Temp"] < lower_temp) |
#    (dataset_2_shift["Temp"] > upper_temp) |
#    (dataset_2_shift["Humidity"] < lower_humidity) |
#    (dataset_2_shift["Humidity"] > upper_humidity) |
#    (dataset_2_shift["Precipitation"] < lower_precipitation) |
#    (dataset_2_shift["Precipitation"] > upper_precipitation) |
#   (dataset_2_shift["Dengue_count"] == forced_outlier_value)
]

# %% [markdown]
# ##### Results after removal

# %%
plt.figure()
plt.scatter(inliers["Temp"], inliers["Dengue_count"], c="blue", label="Kept (Inliers)")
plt.scatter(outliers["Temp"], outliers["Dengue_count"], c="grey", label="Removed (Outliers)")
plt.xlabel("Temperature (Celcius)")
plt.ylabel("Dengue count")
plt.title("Outlier Detection via IQR (Temp vs Dengue Count)")
plt.legend()
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(inliers["Temp"], inliers["Dengue_count"])
print(r, p_value)
# Out:
# -0.40577428062814624 0.08475979940903386

# %%
plt.figure()
plt.scatter(inliers["Humidity"], inliers["Dengue_count"], c="purple", label="Kept (Inliers)")
plt.scatter(outliers["Humidity"], outliers["Dengue_count"], c="grey", label="Removed (Outliers)")
plt.xlabel("Humidity")
plt.ylabel("Dengue count")
plt.title("Outlier Detection via IQR (Humidity vs Dengue Count)")
plt.legend()
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(inliers["Humidity"], inliers["Dengue_count"])
print(r, p_value)
# Out:
# 0.7181386874181218 0.000534485929520405

# %%
plt.figure()
plt.scatter(inliers["Precipitation"], inliers["Dengue_count"], c="magenta", label="Kept (Inliers)")
plt.scatter(outliers["Precipitation"], outliers["Dengue_count"], c="grey", label="Removed (Outliers)")
plt.xlabel("Precipitation")
plt.ylabel("Dengue count")
plt.title("Outlier Detection via IQR (Precipitation vs Dengue Count)")
plt.legend()
plt.show()

# %%
from scipy.stats import pearsonr
r, p_value = pearsonr(inliers["Precipitation"], inliers["Dengue_count"])
print(r, p_value)
# Out:
# 0.5558774414341512 0.013463892419979716

# %% [markdown]
# **Conclusion: Turns out keeping the humidity (no removing the high-humidity nodes) produce better results than if we don't keep them. Seems like only removing the dengue count outliers produce better results (better p-values).**

# %% [markdown]
# #### Identifying features

# %% [markdown]
# Taking all (temperature, humidity, and precipitation) and leaving out the date.

# %%
X = inliers.iloc[:, 1:-1].values # Features (all columns except the first and the last)
y = inliers.iloc[:, -1].values  # Dependent var (last column)

# %%
X
# Out:
# array([[ 29.1 ,  78.4 , 132.5 ],
#        [ 29.8 ,  73.8 ,  24.7 ],
#        [ 29.2 ,  71.9 ,   5.  ],
#        [ 28.7 ,  68.5 ,   0.  ],
#        [ 28.3 ,  68.6 ,   0.  ],
#        [ 28.9 ,  68.7 ,   0.  ],
#        [ 29.5 ,  69.  ,   1.  ],
#        [ 29.7 ,  71.  ,  80.  ],
#        [ 28.7 ,  79.1 , 509.3 ],
#        [ 28.28,  82.  , 607.2 ],
#        [ 27.92,  83.  , 784.5 ],
#        [ 28.75,  78.  , 211.1 ],
#        [ 29.48,  78.  , 142.2 ],
#        [ 29.72,  75.  ,  52.5 ],
#        [ 29.61,  74.  ,  63.3 ],
#        [ 29.06,  71.  ,  99.9 ],
#        [ 29.34,  70.  ,  77.9 ],
#        [ 29.45,  70.  , 131.9 ],
#        [ 29.15,  73.  ,  98.3 ]])

# %%
y
# Out:
# array([1700,  794,  370,  244,  225,  275,  351,  275,  628, 1310, 1028,
#         717,  350,  140,   75,   50,   36,   59,   60])

# %% [markdown]
# #### Splitting into training and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train
# Out:
# array([[ 29.2 ,  71.9 ,   5.  ],
#        [ 29.61,  74.  ,  63.3 ],
#        [ 28.3 ,  68.6 ,   0.  ],
#        [ 29.34,  70.  ,  77.9 ],
#        [ 29.7 ,  71.  ,  80.  ],
#        [ 29.8 ,  73.8 ,  24.7 ],
#        [ 29.72,  75.  ,  52.5 ],
#        [ 29.1 ,  78.4 , 132.5 ],
#        [ 29.15,  73.  ,  98.3 ],
#        [ 29.45,  70.  , 131.9 ],
#        [ 28.28,  82.  , 607.2 ],
#        [ 28.7 ,  79.1 , 509.3 ],
#        [ 29.48,  78.  , 142.2 ],
#        [ 28.75,  78.  , 211.1 ],
#        [ 28.9 ,  68.7 ,   0.  ]])

# %%
y_train
# Out:
# array([ 370,   75,  225,   36,  275,  794,  140, 1700,   60,   59, 1310,
#         628,  350,  717,  275])

# %%
X_test
# Out:
# array([[ 28.7 ,  68.5 ,   0.  ],
#        [ 29.06,  71.  ,  99.9 ],
#        [ 29.5 ,  69.  ,   1.  ],
#        [ 27.92,  83.  , 784.5 ]])

# %%
y_test
# Out:
# array([ 244,   50,  351, 1028])

# %% [markdown]
# # Model training and results

# %% [markdown]
# ## Multiple linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### Testing predictions

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), axis=1))
# Out:
# [[ 179.52  244.  ]
#  [ 221.44   50.  ]
#  [ -35.5   351.  ]
#  [1173.5  1028.  ]]

# %% [markdown]
# #### Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.6236349906452333

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 225.88631569150814

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 191.9781416726188

# %%
from sklearn.metrics import mean_poisson_deviance
poisson_deviance = mean_poisson_deviance(y_test, y_pred)
print("Poisson Deviance:", poisson_deviance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 2
#       1 from sklearn.metrics import mean_poisson_deviance
# ----> 2 poisson_deviance = mean_poisson_deviance(y_test, y_pred)
#       3 print("Poisson Deviance:", poisson_deviance)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
# ...

# %% [markdown]
# Conclusion (2 months shift):
# - Decent R-squared value (0.624).
# - RMSE of 225.9 -> High relative to typical case counts, not great.
# - MAE of 192.0 -> High, consistent with RMSE.
# - Poisson Deviance: N/A (some predictions in this split may be negative — check your test-set predictions before assuming this is computable).
#
# Conclusion (3 months shift):
# - Very good R-squared value (0.844).
# - RMSE of 145.6 -> Moderate (roughly 35-45% of a typical low-season case count).
# - MAE of 115.5 -> Moderate, in line with RMSE.
# - Poisson Deviance: 99.0

# %% [markdown]
# #### What the model looks like

# %%
print("Coefficients:", regressor.coef_)
print("Intercept:", regressor.intercept_)
# Out:
# Coefficients: [-332.73  104.31   -0.99]
# Intercept: 2583.7390344960777

# %% [markdown]
# (2 months shift) prediction = -332.7 * temp + 104.3 * humidity - 0.99 * precipitation + 2583.7
#
# (3 months shift) prediction = -236 * temp + 41.8 * humidity + 0.177 * precipitation + 4210.0

# %% [markdown]
# ## Polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

regressor = Pipeline([("poly", PolynomialFeatures(degree=2, include_bias=False)), 
                      ("linreg", LinearRegression())])

regressor.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(include_bias=False)),
#                 ('linreg', LinearRegression())])

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### Testing predictions

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), axis=1))
# Out:
# [[ 101.17  244.  ]
#  [-271.84   50.  ]
#  [ 414.35  351.  ]
#  [3751.38 1028.  ]]

# %% [markdown]
# #### Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# -12.912847141310076

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1373.38819031639

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 812.8507925993472

# %% [markdown]
# Note: Negative predictions break Poisson deviance math. Thus it is not best used this way. (No possion deviance for this one).

# %% [markdown]
# Yeah, we're not using this. Changing the degrees doesn't help either. Not 2, not 3, not 4, not 5...

# %% [markdown]
# Conclusion (2 months shift):
# - Very bad model (R² = -12.9).
# - Extremely large RMSE (1373.4) and MAE (812.9).
#
# **We will NOT use this model.** Consistent with every other shift tested — polynomial regression simply doesn't work at this sample size (too many parameters for N=15 training rows), regardless of which lag you pick.
#
# Conclusion (3 months shift):
# - Bad model (negative R² of -0.061).
# - Large RMSE (379.3) -> Not good.
# - Large MAE (326.1) -> Not good.
#
# **We will NOT use this model.**

# %% [markdown]
# ## Decision tree regression

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### Testing predictions

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), axis=1))
# Out:
# [[ 225.  244.]
#  [  60.   50.]
#  [ 370.  351.]
#  [1310. 1028.]]

# %% [markdown]
# #### Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8518390801948224

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 141.72684996146637

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 82.5

# %%
from sklearn.metrics import mean_poisson_deviance
poisson_deviance = mean_poisson_deviance(y_test, y_pred)
print("Poisson Deviance:", poisson_deviance)
# Out:
# Poisson Deviance: 17.48068755316098

# %% [markdown]
# [Add 2 months shift data here]
#
# Conclusion (3 months shift):
# - Weak R-squared value (0.086) — this is a large drop from the 2-month-shift version's 0.85, worth flagging rather than smoothing over.
# - Large RMSE (351.9) -> Not good.
# - MAE (226.5) -> Mediocre.
# - Poisson Deviance (209.3) -> Bad (previously "below 20" was the good-threshold language you used; this is 10x that).

# %% [markdown]
# #### What the model looks like

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

feature_names = ["Temp", "Humidity", "Precipitation"]

plt.figure(figsize=(20, 10))
plot_tree(
    regressor,
    feature_names=feature_names,
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()

# %% [markdown]
# ## Random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=300)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### Testing predictions

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), axis=1))
# Out:
# [[ 314.87  244.  ]
#  [ 206.65   50.  ]
#  [ 240.33  351.  ]
#  [1159.86 1028.  ]]

# %% [markdown]
# #### Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8908415889751232

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 121.65050171152875

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 117.51166666666664

# %%
from sklearn.metrics import mean_poisson_deviance
poisson_deviance = mean_poisson_deviance(y_test, y_pred)
print("Poisson Deviance:", poisson_deviance)
# Out:
# Poisson Deviance: 62.21233289298665

# %% [markdown]
# Conclusion (2 months shift):
# - Super good R-squared value (0.92).
# - Very good RSME (below 10000) -> Very good.
# - Below 100 MAE -> Good.
# - Below 100 Posson Deviance -> Good.
#
# **Probably the best model we got.**
#
# Conclusion (3 months shift):
# - Strong R-squared value (0.852) — best of the non-Poisson models here.
# - RMSE (141.7) -> Best RMSE among all models tested.
# - MAE (122.6) -> Comparable to linear regression.
# - Poisson Deviance (89.2) -> Moderate, worse than the decision tree's old 2-month number but far better than the 3-month decision tree.
#
# **Best overall model for this shift, consistent with the 2-month-shift version's conclusion.**

# %% [markdown]
# ## XGBoost regression

# %%
from xgboost import XGBRegressor
regressor = XGBRegressor(n_estimators=500)
regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### Testing predictions

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), axis=1))
# Out:
# [[ 275.    244.  ]
#  [  88.02   50.  ]
#  [ 330.64  351.  ]
#  [1310.   1028.  ]]

# %% [markdown]
# #### Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8481537699699402

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 143.4786569493874

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 92.84417724609375

# %%
from sklearn.metrics import mean_poisson_deviance
poisson_deviance = mean_poisson_deviance(y_test, y_pred)
print("Poisson Deviance:", poisson_deviance)
# Out:
# Poisson Deviance: 22.487403869628906

# %% [markdown]
# Conclusion (2 months shift):
# - Very good R-squared value (0.85). It is interesting that despite being based on the tree models, it doesn't beat random forest.
# - Pretty good RMSE (not too big) -> Good.
# - Below 100 MAE -> Good.
# - Almost 20 Poisson Deviance -> Almost very good.
#
# Conclusion (3 months shift):
# - Decent R-squared value (0.712), noticeably lower than random forest this time (2-month shift had XGBoost close behind at 0.85).
# - RMSE (197.7) -> Worse than random forest.
# - MAE (181.8) -> Worse than random forest.
# - Poisson Deviance (115.6) -> Worse than random forest.
#
# With N this small, XGBoost's extra hyperparameters (500 estimators) likely give it more room to overfit train noise than random forest's simpler bagging — worth trying a smaller `n_estimators` as a sensitivity check before concluding XGBoost is just "worse."

# %% [markdown]
# ## Regularized Poisson regression

# %%
from sklearn.linear_model import PoissonRegressor

regressor = PoissonRegressor(alpha=0.1)
regressor.fit(X_train, y_train)
# Out:
# C:\Users\CTMTM\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\CTMTM\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\CTMTM\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\CTMTM\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### Testing predictions

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), axis=1))
# Out:
# [[ 177.5   244.  ]
#  [ 189.86   50.  ]
#  [ 110.56  351.  ]
#  [1191.96 1028.  ]]

# %% [markdown]
# #### Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7995941634561164

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 164.83160391145182

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 152.69088108294918

# %%
from sklearn.metrics import mean_poisson_deviance
poisson_deviance = mean_poisson_deviance(y_test, y_pred)
print("Poisson Deviance:", poisson_deviance)
# Out:
# Poisson Deviance: 130.58348872821733

# %% [markdown]
# Conclusion (2 months shift):
# - Very good R-squared value (0.80).
# - Okay RMSE -> Average.
# - Below 250 MAE -> Average.
# - Above 80 Poisson Deviance -> Bad.
#
# Conclusion (3 months shift):
# - R² is *negative* (-0.018), not 0.80 like before — this number completely changed and needs a hard edit, not a light one.
# - RMSE (371.5) -> Bad.
# - MAE (329.6) -> Bad.
# - Poisson Deviance (318.0) -> Very bad.
#
# **This model has effectively collapsed: check cell 178's output — every coefficient (Temp, Humidity, Precipitation) is exactly 0.0, meaning the regularization (alpha=0.1) zeroed out every feature and the model is just predicting the constant intercept for every input (467.6 for all four test rows, see cell 170's output). This isn't "a mediocre model," it's a model that learned nothing. Given how small N is at 3-month shift (19), alpha=0.1 may simply be too strong a penalty relative to the data's information content — worth rerunning with a much smaller alpha (e.g. 0.01 or 0.001) before writing this model off.**

# %% [markdown]
# #### What the model looks like

# %%
# Define the names manually in the SAME ORDER as X_train columns
feature_names = ["Temp", "Humidity", "Precipitation"]

coefs = regressor.coef_
intercept = regressor.intercept_

print("Intercept:", intercept)
for name, c in zip(feature_names, coefs):
    print(name, "=", c)
# Out:
# Intercept: 8.963571993548351
# Temp = -0.749636252251059
# Humidity = 0.258831217278801
# Precipitation = -0.0031018040913235907

# %% [markdown]
# **2 Months shift** prediction = exp(8.96357 + (-0.74964 * temp) + (0.25883 * humidity) + (-0.00310 * precipitation))
#
# **3 Months shift** Since every coefficient is 0.0, there's no meaningful prediction formula to report for this run — the model reduced to predicting the mean. This should be stated plainly rather than reporting a formula with zeroed-out terms.

# %% [markdown]
# ## Negative binomial regression

# %% [markdown]
# Negative binomial regression is a generalization of Poisson regression that is specifically useful for over-dispersed data. However, it's not fitting for our data since our data is very small.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

inliers['intercept'] = 1
model = sm.GLM(inliers['Dengue_count'], inliers[['intercept','Temp','Humidity','Precipitation']],
               family=sm.families.NegativeBinomial())

result = model.fit()
print(result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           Dengue_count   No. Observations:                   19
# Model:                            GLM   Df Residuals:                       15
# Model Family:        NegativeBinomial   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -130.52
# Date:                Sun, 13 Sep 2026   Deviance:                       11.002
# Time:                        17:29:47   Pearson chi2:                     8.34
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4017
# Covariance Type:            nonrobust
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# Conclusion (2 months shift):
# Using this model, for each +1 increase in humidity, dengue cases increases by exp(0.2165) = 1.24
# Temperature and precipitation both have non-significant effects (p = 0.416 and p = 0.302), meaning the model cannot reliably conclude that they influence dengue counts.
# **We will NOT use this model for comparison.**
#
# Conclusion (3 months shift):
# Using this model, for each +1°C increase in temperature, dengue cases change by a factor of exp(-0.460) ≈ 0.63 (a 37% decrease), and for each +1 point of humidity, cases increase by a factor of exp(0.076) ≈ 1.08 (an 8% increase) — but neither effect is statistically significant (p = 0.434 and p = 0.417 respectively), nor is precipitation (p = 0.845). None of the three predictors clear significance in this model.
#
# **We will NOT use this model for comparison — consistent with the 2-month-shift version's conclusion, and for the same reason (N too small for a 4-parameter GLM to estimate reliably; note the pseudo-R² here is only 0.335).**

# %% [markdown]
# # Conclusions

# %% [markdown]
# ### 2 Months Shift

# %% [markdown]
# | Model                 | R²   | RMSE   | MAE | Poisson deviance | Notes                             |
# |-----------------------|------|--------|-----|------------------|-----------------------------------|
# | Linear Regression     | 0.62 | 225.9  | 191 | N/A              | Okay                              |
# | Polynomial Regression |-12.9 | 1373.4 | 813 | N/A              | Not fitting at all                |
# | Decision Tree         | 0.85 | 142.2  | 86  | 18               | Best Poisson deviance             |
# | Random Forest         | 0.92 | 103.4  | 95  | 44               | Best overall                      |
# | XGBoost               | 0.85 | 143.5  | 93  | 22               | Good                              |
# | Poisson Regression    | 0.80 | 152.7  | 152 | 131              | Okay, but better than linear reg. |

# %% [markdown]
# ### 3 Months Shift

# %% [markdown]
# | Model                    | R²    | RMSE   | MAE   | Poisson deviance | Notes                                              |
# |---------------------------|-------|--------|-------|-------------------|-----------------------------------------------------|
# | Linear Regression         | 0.844 | 145.6  | 115.5 | 99.0               | Solid, stable                                        |
# | Polynomial Regression     | -0.061| 379.3  | 326.1 | N/A               | Not fitting at all                                    |
# | Decision Tree             | 0.086 | 352.0  | 226.5 | 209.3             | Collapsed relative to 2-month-shift version           |
# | Random Forest             | 0.852 | 141.7  | 122.6 | 89.2              | **Best overall**                                      |
# | XGBoost                   | 0.712 | 197.7  | 181.8 | 115.6             | Middling, likely overfit given small N                |
# | Poisson Regression        | -0.018| 371.5  | 329.6 | 318.0             | Collapsed — all coefficients zeroed by regularization  |
# | Negative Binomial (GLM)   | —     | —      | —     | —                 | No predictor reaches significance; not used for comparison |
#
# **Overall: Random Forest remains the best-performing model even after switching from 2-month to 3-month shift, consistent across both datasets. Linear Regression is a stable, interpretable runner-up. The tree-based Decision Tree and the regularized Poisson model both degraded sharply on this shift — worth investigating (small-N instability vs. a genuine property of the 3-month window) before drawing conclusions about shift choice from model performance alone.**
